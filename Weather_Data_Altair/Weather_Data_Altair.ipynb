# %% [markdown]
# # DS4200 Homework 2
#
# Due: Friday Feb 7th @ 11:59 PM EST
#
# ### Submission Instructions
# Submit this `ipynb` file included with the coding results as well as the picture in the last question to Gradescope (this can also be done via the assignment on Canvas).  To ensure that your submitted files represent your latest code, make sure to give a fresh `Kernel > Restart & Run All` just before uploading the files to gradescope.
#
# ### Tips for success
# - Start early
# - Make use of Piazza
# - Make use of Office hour
# - Remember to use cells and headings to make the notebook easy to read (if a grader cannot find the answer to a problem, you will receive no points for it)
# - Under no circumstances may one student view or share their ungraded homework or quiz with another student [(see also)](http://www.northeastern.edu/osccr/academic-integrity), though you are welcome to **talk about** (not show each other) the problems.

# %% [markdown]
# ### Part 1 - Encodings (25 points)
#
# Navigate to [datavizproject](https://datavizproject.com/) and take some time to freely browse the website and explore. After browsing, find a visual encoding on the webpage that is new to you (i.e. one you have never seen before).
#
# ##### Quesiton 1 (5 pts)
# Put in this section a screenshot and hyperlink to the visual encoding that is new to you.

# %% [markdown]
# ![Screenshot 2025-02-02 at 11.05.31 AM.png](attachment:a9bba4a8-1419-41c4-bd87-c6a428d937a3.png)
# https://datavizproject.com/data-type/chord-diagram/

# %% [markdown]
# ##### Question 2 (5 pts)
#
# Add a short paragraph explaining what you like and do not like about the new-to-you visual encoding you selected.

# %% [markdown]
# At first glance, it is difficult to understand what the graph is trying to convey in terms of visualization. For instance, all sections of the nodes appear to be interconnected, which differs from typical visualization graphs where each node represents a distinct category of data. In contrast, the chord diagram presents data in a more unconventional manner, focusing on a matrix to highlight correlations and disparities within the data. Without prior context, the diagram may initially appear somewhat radical or chaotic.

# %% [markdown]
# Take a look at the toolbar at the top of the webpage. Note how visualizations are organized (categorized) in multiple ways to help the user identify a visual encoding depending on whether they care about data type, composition, or task.
#
# ##### Question 3 (5 pts)
#
# What does “Input” mean? How are the visualizations categorized in this scheme? How does (if at all) this map to the language in our readings?

# %% [markdown]
# "Input" refers to the type of data used to design a visualization. Different data structures result in different categories of visualizations. Some visualizations are categorized based on data structures such as numerical, categorical, relational, hierarchical, geographical, and spatial data. This classification provides a wide range of options when choosing the appropriate visualization technique to effectively represent and communicate insights from the dataset. Ensuring the right match between data and visualization design enhances accuracy and clarity in data interpretation.

# %% [markdown]
# ##### Question 4 (5 pts)
#
# What does “Shape” mean? How are the visualizations categorized in this scheme? How does (if at all) this map to the language in our readings?

# %% [markdown]
# "Shape" refers to the overall structure and form of a visualization, determining how the dataset is visually oriented and presented. The "Shape" category sorts each graph based on its general form, such as circles, rectangles, stars, lines, and points. This helps users select a visualization that aligns with their preferred way of displaying relationships or correlations within their dataset. Choosing the right visualization shape enhances comprehension and clarity, ensuring that the data is effectively presented and produce the best analytical insights.

# %% [markdown]
# ##### Question 5 (5 pts)
#
# What does “Function” mean? How are the visualizations categorized in this scheme? How does (if at all) this map to the language in our readings?

# %% [markdown]
# "Function" refers to the primary purpose or analytical goal that a visualization is conveying. Different visualizations serve different purposes when presenting a dataset, such as comparison, distribution, correlation, and concept visualization. Choosing the right function helps users meet their specific data analysis needs and enhances the effectiveness of the visualization. This ensures that the visualization is more intuitive and meaningful, making it easier to understand and interpret the data.

# %% [markdown]
# ### Part 2 - Xenographics (15 points)
#
# Watch the following talk about the Xenographics project by Maarten Lambrechts from the OpenVis Conf (2018): [https://www.youtube.com/watch?v=fp-WNqaQG0s](https://www.youtube.com/watch?v=fp-WNqaQG0s)
#
# Next, explore the online collection: https://xeno.graphics/.

# %% [markdown]
# Then, write a 1-2 paragraph response (minimum 200 words) which addresses the following questions:
#
# - What is the Xenographics project, and what is its goal?
# - How are the visualizations categorized and organized on the project website?
# - What was the most interesting or surprising thing you learned by watching the talk and exploring the website?
# - Provide a link and short description to your favorite visualization on the website.
#
# Your 1–2 paragraphs evidence a critical and thoughtful effort and answer the posed questions. Your writing shows a high degree of attention to logic and reasoning of points, is written in a clear manner, and words are chosen to precisely express the intended meaning and support reader comprehension. There are few English spelling or grammar mistakes.

# %% [markdown]
# The Xenographics project, created by Maarten Lambrechts, is a collection of unconventional and experimental data visualizations that differ from traditional chart types like bar graphs or line charts. The project's goal is to explore and demonstrate unique, often underutilized visualization techiques that may offer an unexpected usefulness when it comes to representing a dataset. By compiling these different type of "weird" visualizations, the project encourages creative thinking in data visualization, challenging conventional norms while promoting new perspectives on data visualization.
#
# On the project website, visualizations are categorized based on their structural and functional features. Each graph includes filters that allow users to explore different types of visualizations, highlighting their distinctiveness in form and data representation. The collection serves as an inspiration for data visualization practitioners looking for alternative ways to communicate insights beyond standard charts.
#
# One of the most interesting insights from the talk and website exploration was the idea that many of these unconventional visualizations are not necessarily “better” than traditional charts but offer new ways to explore and communicate data. The talk emphasized how some visualizations are more artistic or intriguing rather than strictly functional, illustrating the importance of considering both effectiveness and creativity in presenting the dataset.
#
# One of my favorite visualization on the website is the 3D Kiviat plot. This visualization is designed to represent multidimensional data using a three-dimensional stacked format. Each stack corresponds to an experiment, with its axes representing different input parameters. The stacks are ordered based on the quantity of interest and are color-coded to indicate their difference from a reference experiment.

# %% [markdown]
# ### Part 3 - Basic data analysis with Altair (40 points)
#
# We are going to use the same Weather data from Homework 1 but use Altair to create the data visualziation.
#
# ##### Question 1 (10 points)
#
# Recreate the figure in Part 3 Question 2 in Homework 1 with Altair. Include necessary title and labels. Here is the question again:
#
#     Generate a data visualization to show the relationship between max temperature and weather type.

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
import altair as alt
from vega_datasets import data

weather = data.seattle_weather()
weather.head()
# Out:
#         date  precipitation  temp_max  temp_min  wind  weather
# 0 2012-01-01            0.0      12.8       5.0   4.7  drizzle
# 1 2012-01-02           10.9      10.6       2.8   4.5     rain
# 2 2012-01-03            0.8      11.7       7.2   2.3     rain
# 3 2012-01-04           20.3      12.2       5.6   4.7     rain
# 4 2012-01-05            1.3       8.9       2.8   6.1     rain

# %%
# Create the relationship between max temperature and weather type Altair chart
chart = alt.Chart(weather).mark_point().encode(
    alt.X('temp_max:Q'),  
    alt.Y('weather:N'),         
    alt.Color('weather:N')   
).properties(
    title =" Max Temperature vs Weather Type in Seattle"
)

# Show the chart
chart
# Out:
# alt.Chart(...)

# %% [markdown]
# ##### Question 2 (10 points)
#
# Recreate the figure in Part 3 Question 3 in Homework 1 with Altair. Include necessary title and labels. Here is the question again:
#
#     Generate a data visualization to show the relationship between max temperature and min temperature, and then show different color for differnet weather type.

# %%
# Create a scatter plot
chart = alt.Chart(weather).mark_circle().encode(
    alt.X('temp_max:Q'), 
    alt.Y('temp_min:Q'), 
    alt.Color('weather:N')
).properties(
    title='Max Temp vs Min Temp with Weather Type'
)
chart
# Out:
# alt.Chart(...)

# %% [markdown]
# ##### Question 3 (10 points)
#
# Create a facet figure in Altair with 2 row and 3 columns. For each panel in the facet figure, it shows a scatter plot between the max and min temperature for one type of weather. Use the wind speed to color the points. Also add interaction to show the max and min temperature and wind speed for each data point. Include necessary title and labels.

# %%
# Create the facet chart
facet_chart = alt.Chart(weather).mark_circle().encode(
    alt.X('temp_max:Q'), 
    alt.Y('temp_min:Q'), 
    alt.Color('wind:Q', title = 'Wind Speed'),
    alt.Tooltip(['temp_max', 'temp_min', 'wind', 'weather']) 
).facet(
    facet='weather:N',  
    columns=3  
).properties(
    title='Max Temp vs Min Temp by Weather Type (Colored by Wind Speed)'
)
facet_chart
# Out:
# alt.FacetChart(...)

# %% [markdown]
# ##### Question 4 (10 points)
#
# Create a compound figure with at least two types of marks. Show the trend of average temperature (the average of min and max temperature) in 4 years. Note, just use the `date` as X attribute, no need to aggragate for years and you will get a wide figure. Include necessary title and labels.

# %%
# Calculate the average temperature 
weather['avg_temp'] = (weather['temp_max'] + weather['temp_min']) / 2

# Create line chart
line_chart = alt.Chart(weather).mark_line(color='blue').encode(
    alt.X('date:T'), 
    alt.Y('avg_temp:Q')
).properties(
    title='Trend of Average Temperature Over 4 Years'
)

# Create point chart
points_chart = alt.Chart(weather).mark_circle(color='red').encode(
    alt.X('date:T'), 
    alt.Y('avg_temp:Q'),    
)

# Combine the line and points marks
compound_chart = line_chart + points_chart
compound_chart
# Out:
# alt.LayerChart(...)

# %% [markdown]
# ### Part 4 - Colors (20 points)
#
# Please email the instructor if you have problems to complete the color-related homework.
#
# ##### Question 1 (5 points)
#
# Following is a density plot for the wind speed for all five types of weather. Is there any problems in the figure? Try to name at least two ways you can do to re-design the figure (change the mark/channel/encoding etc.)

# %% [markdown]
# <img src="https://i.ibb.co/QNfQ2tb/visualization.png" alt="visualization" border="0">

# %% [markdown]
# The density curves for the five weather types overlap significantly, making it difficult for the viewer to distinguish between them, especially for the weather types with similar wind speed distributions. The color choice could also be improved, with a more diverse and distinct color assignment to help better differentiate between the curves. Additionally, the tooltip feature could be included to display the exact density values when hovering over the curves. I would implement different colors that are very distinct to display the density difference for each weather type and add tooltip for the encoding part for better interactivity and value interpretation.

# %% [markdown]
# ##### Question 2 （5 points）
#
# Go to [http://vrl.cs.brown.edu/color](http://vrl.cs.brown.edu/color) and select another color palette for the figure. Explain how to set the configuration to get the color palette. Take a screenshot of the color palette you have chosen on the website and then go to [https://www.color-blindness.com/coblis-color-blindness-simulator/](https://www.color-blindness.com/coblis-color-blindness-simulator/) and upload the screenshot. Discuss how one of the color-blind illness affects the figure.

# %% [markdown]
# Number of colors: 5
#
# Sore importance: all four all the way down
#
# Hue Filters: no change
#
# Lightness range: 25-80
#
# Affect: When choosing blue-blind/Tritanopia option from the dichromatic view, color that has blue element, in this case the green color, can change to blue and the other blue color also change. More specifically, the very green color (rgb(55,196,84)) would change to blue color whereas brown and red does not really change( a little for red). Then the very right color would change more to purple color.

# %% [markdown]
# ![Screenshot](colorblind.png)

# %% [markdown]
# ![Screenshot](color2.png)

# %% [markdown]
# ##### Question 3 (10 points)
#
# Based on what we have learned in the lecture, try to create an example for the color illusion. You can choose from:
# + Simultaneous Contrast: Colors look different depending on the surrounding colors (light and dark).
# + Gradient Illusion: how the gradient background affect the solid color in front of it.
# + Color Context Effects: The same color can appear lighter, darker, or even as a different hue depending on its background, eg: the border.
#
# Attach the picture of your design to the homework (You can zip the picture and .ipynb file when you submit it or submit the GitHub repo). You can choose any tool for your design, PPT, Canvas, Photoshop etc. Do not directly copy the lecture examples. Write a few sentence about your design. How you design it and which illusion you are addressing.

# %% [markdown]
# Two large squares are placed next to each other, one with a light purple background on the left and the other with a blue background on the right. Inside each large square, there are two identical magenta colored smaller squares. At first glance, the small square on the left appears to be a darker shade of magenta, while the small square on the right looks lighter. However, both small squares are actually the same color.
#
# This demonstrates the Color Context Effect, where the surrounding background influences the perceived color of the objects within it.

# %% [markdown]
# ![Screenshot](R.png)
